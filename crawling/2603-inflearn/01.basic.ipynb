# %%
print('hello python')
# Out:
# hello python

# %%
print('hello')
# Out:
# hello

# %%
# 설치 방법
# !pip install requests
# Out:
#   Cell In[2], line 2
#     pip install requests
#         ^
# SyntaxError: invalid syntax
