# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://startcoding.pythonanywhere.com/basic")

html = response.text

soup = BeautifulSoup(html, 'html.parser')

# 포레스트 이론

# 숲 - 페이지 전체 HTML
# 나무 - 원하는 정보를 모두 담는 태그

# %%
# select(): 선택자에 매칭되는 태그 전체를 리스트로 변환

soup.select('.product')
# Out:
# [<div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product01.png"/>
#  <div class="product-label">
#  <span class="new">HOT</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product1_detail.html">에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT</a></h3>
#  <h4 class="product-price">1,419,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star-half-o"></i>
#
#
#  												(16)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product02.png"/>
#  <div class="product-label">
#  <span class="new">HOT</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product2_detail.html">삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro</a></h3>
#  <h4 class="product-price">549,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#
#
#  												(405)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product03.png"/>
#  <div class="product-label">
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product3_detail.html">레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB</a></h3>
#  <h4 class="product-price">529,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#
#
#  												(903)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product04.png"/>
#  <div class="product-label">
#  <span class="sale">-3%</span>
#  <span class="new">HOT</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product4_detail.html">레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR</a></h3>
#  <h4 class="product-price">624,000원
#
#  										<del class="product-old-price">649,000</del>
#  </h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#
#
#  												(1)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product05.png"/>
#  <div class="product-label">
#  <span class="new">HOT</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product5_detail.html">LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K</a></h3>
#  <h4 class="product-price">1,135,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star-half-o"></i>
#
#
#  												(155)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product06.png"/>
#  <div class="product-label">
#  <span class="new">HOT</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product6_detail.html">베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB</a></h3>
#  <h4 class="product-price">398,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star-half-o"></i>
#
#
#  												(1541)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product07.png"/>
#  <div class="product-label">
#  <span class="sale">-18%</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product7_detail.html">레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 512GB, 16GB, Free DOS, 82XD002XKR</a></h3>
#  <h4 class="product-price">899,000원
#
#  										<del class="product-old-price">1,099,000</del>
#  </h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#
#
#  												(106)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product08.png"/>
#  <div class="product-label">
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product8_detail.html">레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 16GB, Free DOS, 82XF001RKR</a></h3>
#  <h4 class="product-price">929,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#
#
#  												(118)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product09.png"/>
#  <div class="product-label">
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product9_detail.html">에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB, Free DOS, SFG16-71-51BY</a></h3>
#  <h4 class="product-price">1,008,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star-half-o"></i>
#
#
#  												(16)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>,
#  <div class="product">
#  <div class="product-img">
#  <img alt="" src="../static/img/product10.png"/>
#  <div class="product-label">
#  <span class="new">HOT</span>
#  </div>
#  </div>
#  <div class="product-body">
#  <p class="product-category">노트북</p>
#  <h3 class="product-name"><a href="#product10_detail.html">삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home</a></h3>
#  <h4 class="product-price">1,149,000원
#
#  									</h4>
#  <div class="product-rating sub_cnt">
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#  <i class="fa fa-star"></i>
#
#
#  												(687)
#  									</div>
#  <div class="product-btns">
#  <button class="add-to-wishlist"><i class="fa fa-heart-o"></i><span class="tooltipp">add to wishlist</span></button>
#  <!-- <button class="add-to-compare"><i class="fa fa-exchange"></i><span class="tooltipp">add to compare</span></button> -->
#  <button class="quick-view"><i class="fa fa-eye"></i><span class="tooltipp">quick
#  												view</span></button>
#  </div>
#  </div>
#  <div class="add-to-cart">
#  <button class="add-to-cart-btn"><i class="fa fa-shopping-cart"></i> add to
#  										cart</button>
#  </div>
#  </div>]

# %%
items = soup.select('.product')

for item in items:
    category = soup.select_one('.product-category').text
    name = soup.select_one('.product-name').text
    price = soup.select_one('.product-price').text.strip().replace(',', '').replace('원', '')
    link = soup.select_one('.product-name > a').attrs['href']
    print(category, '/', name, '/', link, '/', price)
# Out:
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000

# %%
items = soup.select('.product')

for item in items:
    category = item.select_one('.product-category').text
    name = item.select_one('.product-name').text
    price = item.select_one('.product-price').text.strip().replace(',', '').replace('원', '')
    link = item.select_one('.product-name > a').attrs['href']
    print(category, '/', name, '/', link, '/', price)
# Out:
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT / #product1_detail.html / 1419000
# 노트북 / 삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro / #product2_detail.html / 549000
# 노트북 / 레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB / #product3_detail.html / 529000
# 노트북 / 레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR / #product4_detail.html / 624000
#
# 										649000
# 노트북 / LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K / #product5_detail.html / 1135000
# 노트북 / 베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB / #product6_detail.html / 398000
# 노트북 / 레노버 아이디어패드 슬림 5i 14IRL 14, Cloud Grey, 코어i5, 512GB, 16GB, Free DOS, 82XD002XKR / #product7_detail.html / 899000
#
# 										1099000
# 노트북 / 레노버 아이디어패드 슬림 5 16IRL 16, Cloud Grey, 512GB, 16GB, Free DOS, 82XF001RKR / #product8_detail.html / 929000
# 노트북 / 에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i5, 512GB, 16GB, Free DOS, SFG16-71-51BY / #product9_detail.html / 1008000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 1149000

# %%
items = soup.select('.product')

for item in items:
    # category = item.select_one('.product-category').text
    # name = item.select_one('.product-name').text
    price = item.select_one('.product-price').text.split('원')
    # link = item.select_one('.product-name > a').attrs['href']
    print(price)
# Out:
# ['1,419,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['549,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['529,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['624,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t649,000\n']
# ['1,135,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['398,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['899,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t1,099,000\n']
# ['929,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['1,008,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']
# ['1,149,000', '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t']

# %%
items = soup.select('.product')

for item in items:
    # category = item.select_one('.product-category').text
    # name = item.select_one('.product-name').text
    price = item.select_one('.product-price').text.split('원')[0].replace(',', '')
    # link = item.select_one('.product-name > a').attrs['href']
    print(price)
# Out:
# 1419000
# 549000
# 529000
# 624000
# 1135000
# 398000
# 899000
# 929000
# 1008000
# 1149000

# %%
items = soup.select('.product')

for item in items:
    # category = item.select_one('.product-category').text
    # name = item.select_one('.product-name').text
    price = item.select_one('.product-price').text.split('원')[0].replace(',', '')
    # link = item.select_one('.product-name > a').attrs['href']
    print(price)
# Out:
# 1419000
# 549000
# 529000
# 624000
# 1135000
# 398000
# 899000
# 929000
# 1008000
# 1149000

# %%
items = soup.select('.product')

for item in items:
    # category = item.select_one('.product-category').text
    # name = item.select_one('.product-name').text
    price = item.select_one('.product-price').text.split('원')[0].replace(',', '')
    # link = item.select_one('.product-name > a').attrs['href']
    print(category, '/', name, '/', link, '/', price)
# Out:
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 1419000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 549000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 529000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 624000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 1135000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 398000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 899000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 929000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 1008000
# 노트북 / 삼성전자 갤럭시북 2 15.6, 500GB, 실버, NT550XED-K78AS, 코어i7, 16GB, WIN11 Home / #product10_detail.html / 1149000
